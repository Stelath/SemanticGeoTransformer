# %%
import re
import matplotlib.pyplot as plt

# Define regex pattern for validation log entries
val_pattern = re.compile(r"""
    \[(?P<timestamp>[\d\- :]+)\]      # Timestamp
    \s+\[CRIT\]                       # Log level
    \s+\[Val\]\s+Epoch:\s+(?P<epoch>\d+),  # Epoch
    \s+c_loss:\s+(?P<c_loss>[\d\.]+), # c_loss
    \s+f_loss:\s+(?P<f_loss>[\d\.]+), # f_loss
    \s+loss:\s+(?P<loss>[\d\.]+),     # loss
    \s+PIR:\s+(?P<PIR>[\d\.]+),       # PIR
    \s+IR:\s+(?P<IR>[\d\.]+),         # IR
    \s+RRE:\s+(?P<RRE>[\d\.]+),       # RRE
    \s+RTE:\s+(?P<RTE>[\d\.]+),       # RTE
    \s+RR:\s+(?P<RR>[\d\.]+),         # RR
    \s+time:\s+[\d\.]+s/[\d\.]+s      # time
""", re.VERBOSE)

# Function to read log and extract validation entries
def extract_val_data(log_file):
    validation_data = []

    with open(log_file, 'r') as file:
        for line in file:
            match = val_pattern.search(line)
            if match:
                data = match.groupdict()
                validation_data.append({
                    'epoch': int(data['epoch']),
                    'loss': float(data['loss']),
                    'RRE': float(data['RRE']),
                    'RTE': float(data['RTE']),
                    'RR': float(data['RR'])
                })

    return validation_data

# Graphing function
def plot_validation_data(validation_data):
    epochs = [entry['epoch'] for entry in validation_data]
    losses = [entry['loss'] for entry in validation_data]
    RREs = [entry['RRE'] for entry in validation_data]
    RTEs = [entry['RTE'] for entry in validation_data]

    plt.figure(figsize=(12, 8))

    plt.subplot(3, 1, 1)
    plt.plot(epochs, losses, marker='o', label='Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.legend()

    plt.subplot(3, 1, 2)
    plt.plot(epochs, RREs, marker='o', color='orange', label='RRE')
    plt.xlabel('Epoch')
    plt.ylabel('RRE')
    plt.grid(True)
    plt.legend()

    plt.subplot(3, 1, 3)
    plt.plot(epochs, RTEs, marker='o', color='green', label='RTE')
    plt.xlabel('Epoch')
    plt.ylabel('RTE')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
log_file = '/project/bli4/maps/wacv/GeoTransformer/weights/ORFD/long_log.log'  # Replace with your log file path
validation_data = extract_val_data(log_file)

# %%
validation_data
# Out:
# [{'epoch': 1, 'loss': 1.77, 'RRE': 30.837, 'RTE': 1.124, 'RR': 0.414},
#  {'epoch': 2, 'loss': 2.728, 'RRE': 9.044, 'RTE': 0.511, 'RR': 0.741},
#  {'epoch': 3, 'loss': 1.934, 'RRE': 16.351, 'RTE': 0.622, 'RR': 0.745},
#  {'epoch': 4, 'loss': 2.241, 'RRE': 8.726, 'RTE': 0.469, 'RR': 0.841},
#  {'epoch': 5, 'loss': 2.144, 'RRE': 10.648, 'RTE': 0.492, 'RR': 0.808},
#  {'epoch': 6, 'loss': 2.037, 'RRE': 7.592, 'RTE': 0.445, 'RR': 0.824},
#  {'epoch': 7, 'loss': 2.418, 'RRE': 5.117, 'RTE': 0.365, 'RR': 0.862},
#  {'epoch': 8, 'loss': 3.014, 'RRE': 5.709, 'RTE': 0.372, 'RR': 0.862},
#  {'epoch': 9, 'loss': 2.184, 'RRE': 5.752, 'RTE': 0.394, 'RR': 0.891},
#  {'epoch': 10, 'loss': 2.487, 'RRE': 7.805, 'RTE': 0.426, 'RR': 0.879},
#  {'epoch': 11, 'loss': 2.403, 'RRE': 5.067, 'RTE': 0.387, 'RR': 0.908},
#  {'epoch': 12, 'loss': 2.474, 'RRE': 4.224, 'RTE': 0.341, 'RR': 0.891},
#  {'epoch': 13, 'loss': 2.21, 'RRE': 2.647, 'RTE': 0.317, 'RR': 0.921},
#  {'epoch': 14, 'loss': 2.681, 'RRE': 4.847, 'RTE': 0.354, 'RR': 0.887},
#  {'epoch': 15, 'loss': 2.412, 'RRE': 5.186, 'RTE': 0.357, 'RR': 0.874},
#  {'epoch': 16, 'loss': 2.474, 'RRE': 3.292, 'RTE': 0.319, 'RR': 0.916},
#  {'epoch': 17, 'loss': 2.533, 'RRE': 5.333, 'RTE': 0.347, 'RR': 0.904},
#  {'epoch': 18, 'loss': 2.733, 'RRE': 3.406, 'RTE': 0.3, 'RR': 0.908},
#  {'epoch': 19, 'loss': 2.719, 'RRE': 4.93, 'RTE': 0.352, 'RR': 0.904},
#  {'epoch': 20, 'loss': 2.799, 'RRE': 4.375, 'RTE': 0.324, 'RR': 0.925},
#  {'epoch': 21, 'loss': 3.054, 'RRE': 4.43, 'RTE': 0.333, 'RR': 0.941},
#  {'epoch': 22, 'loss': 2.788, 'RRE': 4.434, 'RTE': 0.323, 'RR': 0.916},
#  {'epoch': 23, 'loss': 3.121, 'RRE': 3.699, 'RTE': 0.294, 'RR': 0.941},
#  {'epoch': 24, 'loss': 3.366, 'RRE': 3.836, 'RTE': 0.298, 'RR': 0.937},
#  {'epoch': 25, 'loss': 2.462, 'RRE': 6.203, 'RTE': 0.364, 'RR': 0.891},
#  {'epoch': 26, 'loss': 3.526, 'RRE': 4.447, 'RTE': 0.316, 'RR': 0.937},
#  {'epoch': 27, 'loss': 3.024, 'RRE': 4.396, 'RTE': 0.313, 'RR': 0.929},
#  {'epoch': 28, 'loss': 3.419, 'RRE': 4.212, 'RTE': 0.3, 'RR': 0.941},
#  {'epoch': 29, 'loss': 2.523, 'RRE': 2.985, 'RTE': 0.289, 'RR': 0.933},
#  {'epoch': 30, 'loss': 2.838, 'RRE': 8.477, 'RTE': 0.385, 'RR': 0.929},
#  {'epoch': 31, 'loss': 2.583, 'RRE': 7.368, 'RTE': 0.356, 'RR': 0.921},
#  {'epoch': 32, 'loss': 2.349, 'RRE': 2.992, 'RTE': 0.294, 'RR': 0.921},
#  {'epoch': 33, 'loss': 2.714, 'RRE': 2.591, 'RTE': 0.29, 'RR': 0.921},
#  {'epoch': 34, 'loss': 3.006, 'RRE': 4.241, 'RTE': 0.291, 'RR': 0.941},
#  {'epoch': 35, 'loss': 3.41, 'RRE': 7.571, 'RTE': 0.398, 'RR': 0.916},
#  {'epoch': 36, 'loss': 2.782, 'RRE': 9.653, 'RTE': 0.418, 'RR': 0.891},
#  {'epoch': 37, 'loss': 2.583, 'RRE': 3.013, 'RTE': 0.304, 'RR': 0.921},
#  {'epoch': 38, 'loss': 2.492, 'RRE': 5.974, 'RTE': 0.35, 'RR': 0.895},
#  {'epoch': 39, 'loss': 2.275, 'RRE': 5.232, 'RTE': 0.351, 'RR': 0.921},
#  {'epoch': 40, 'loss': 2.457, 'RRE': 6.278, 'RTE': 0.36, 'RR': 0.866},
#  {'epoch': 41, 'loss': 2.505, 'RRE': 7.109, 'RTE': 0.373, 'RR': 0.887},
#  {'epoch': 42, 'loss': 2.629, 'RRE': 4.38, 'RTE': 0.346, 'RR': 0.895},
#  {'epoch': 43, 'loss': 3.086, 'RRE': 8.003, 'RTE': 0.394, 'RR': 0.87},
#  {'epoch': 44, 'loss': 2.959, 'RRE': 6.671, 'RTE': 0.369, 'RR': 0.912},
#  {'epoch': 45, 'loss': 3.354, 'RRE': 4.3, 'RTE': 0.299, 'RR': 0.95},
#  {'epoch': 46, 'loss': 3.259, 'RRE': 7.218, 'RTE': 0.345, 'RR': 0.937},
#  {'epoch': 47, 'loss': 2.618, 'RRE': 6.073, 'RTE': 0.337, 'RR': 0.908},
#  {'epoch': 48, 'loss': 3.211, 'RRE': 6.579, 'RTE': 0.343, 'RR': 0.908},
#  {'epoch': 49, 'loss': 3.731, 'RRE': 2.227, 'RTE': 0.265, 'RR': 0.937},
#  {'epoch': 50, 'loss': 2.75, 'RRE': 3.656, 'RTE': 0.295, 'RR': 0.941},
#  {'epoch': 51, 'loss': 2.717, 'RRE': 8.856, 'RTE': 0.399, 'RR': 0.891},
#  {'epoch': 52, 'loss': 3.195, 'RRE': 6.553, 'RTE': 0.351, 'RR': 0.921},
#  {'epoch': 53, 'loss': 2.685, 'RRE': 7.095, 'RTE': 0.365, 'RR': 0.883},
#  {'epoch': 54, 'loss': 2.33, 'RRE': 7.943, 'RTE': 0.419, 'RR': 0.854},
#  {'epoch': 55, 'loss': 2.81, 'RRE': 8.101, 'RTE': 0.395, 'RR': 0.883},
#  {'epoch': 56, 'loss': 2.83, 'RRE': 9.269, 'RTE': 0.405, 'RR': 0.879},
#  {'epoch': 57, 'loss': 2.737, 'RRE': 5.578, 'RTE': 0.34, 'RR': 0.9},
#  {'epoch': 58, 'loss': 2.779, 'RRE': 12.132, 'RTE': 0.464, 'RR': 0.854},
#  {'epoch': 59, 'loss': 2.653, 'RRE': 4.145, 'RTE': 0.31, 'RR': 0.946},
#  {'epoch': 60, 'loss': 2.687, 'RRE': 8.118, 'RTE': 0.389, 'RR': 0.904},
#  {'epoch': 61, 'loss': 2.701, 'RRE': 10.416, 'RTE': 0.414, 'RR': 0.891},
#  {'epoch': 62, 'loss': 2.713, 'RRE': 3.916, 'RTE': 0.297, 'RR': 0.908},
#  {'epoch': 63, 'loss': 2.655, 'RRE': 11.979, 'RTE': 0.45, 'RR': 0.854},
#  {'epoch': 64, 'loss': 3.154, 'RRE': 11.583, 'RTE': 0.45, 'RR': 0.887},
#  {'epoch': 65, 'loss': 2.902, 'RRE': 8.431, 'RTE': 0.393, 'RR': 0.921},
#  {'epoch': 66, 'loss': 2.081, 'RRE': 7.928, 'RTE': 0.386, 'RR': 0.929},
#  {'epoch': 67, 'loss': 3.219, 'RRE': 8.731, 'RTE': 0.395, 'RR': 0.912},
#  {'epoch': 68, 'loss': 2.861, 'RRE': 13.338, 'RTE': 0.498, 'RR': 0.874},
#  {'epoch': 69, 'loss': 2.529, 'RRE': 10.547, 'RTE': 0.439, 'RR': 0.87},
#  {'epoch': 70, 'loss': 3.667, 'RRE': 7.88, 'RTE': 0.376, 'RR': 0.925},
#  {'epoch': 71, 'loss': 2.99, 'RRE': 11.581, 'RTE': 0.468, 'RR': 0.828},
#  {'epoch': 72, 'loss': 2.991, 'RRE': 11.004, 'RTE': 0.438, 'RR': 0.849},
#  {'epoch': 73, 'loss': 3.327, 'RRE': 14.131, 'RTE': 0.495, 'RR': 0.858},
#  {'epoch': 74, 'loss': 2.901, 'RRE': 11.855, 'RTE': 0.479, 'RR': 0.883},
#  {'epoch': 75, 'loss': 2.986, 'RRE': 11.686, 'RTE': 0.446, 'RR': 0.908},
#  {'epoch': 76, 'loss': 2.952, 'RRE': 7.328, 'RTE': 0.359, 'RR': 0.887},
#  {'epoch': 77, 'loss': 2.878, 'RRE': 8.845, 'RTE': 0.391, 'RR': 0.891},
#  {'epoch': 78, 'loss': 3.336, 'RRE': 7.62, 'RTE': 0.374, 'RR': 0.883},
#  {'epoch': 79, 'loss': 2.888, 'RRE': 11.381, 'RTE': 0.44, 'RR': 0.845},
#  {'epoch': 80, 'loss': 2.547, 'RRE': 10.118, 'RTE': 0.438, 'RR': 0.854},
#  {'epoch': 81, 'loss': 2.765, 'RRE': 8.286, 'RTE': 0.418, 'RR': 0.837},
#  {'epoch': 82, 'loss': 3.11, 'RRE': 8.59, 'RTE': 0.397, 'RR': 0.849},
#  {'epoch': 83, 'loss': 3.995, 'RRE': 9.795, 'RTE': 0.388, 'RR': 0.933},
#  {'epoch': 84, 'loss': 3.715, 'RRE': 7.532, 'RTE': 0.366, 'RR': 0.883},
#  {'epoch': 85, 'loss': 2.807, 'RRE': 14.849, 'RTE': 0.521, 'RR': 0.808},
#  {'epoch': 86, 'loss': 2.867, 'RRE': 15.499, 'RTE': 0.517, 'RR': 0.824},
#  {'epoch': 87, 'loss': 3.599, 'RRE': 9.064, 'RTE': 0.407, 'RR': 0.887},
#  {'epoch': 88, 'loss': 3.351, 'RRE': 7.024, 'RTE': 0.347, 'RR': 0.954},
#  {'epoch': 89, 'loss': 3.268, 'RRE': 9.082, 'RTE': 0.41, 'RR': 0.883},
#  {'epoch': 90, 'loss': 3.629, 'RRE': 12.537, 'RTE': 0.476, 'RR': 0.82},
#  {'epoch': 91, 'loss': 2.951, 'RRE': 6.705, 'RTE': 0.36, 'RR': 0.87},
#  {'epoch': 92, 'loss': 2.918, 'RRE': 7.342, 'RTE': 0.343, 'RR': 0.887},
#  {'epoch': 93, 'loss': 2.998, 'RRE': 6.758, 'RTE': 0.354, 'RR': 0.895},
#  {'epoch': 94, 'loss': 2.898, 'RRE': 8.196, 'RTE': 0.404, 'RR': 0.887},
#  {'epoch': 95, 'loss': 2.863, 'RRE': 7.98, 'RTE': 0.371, 'RR': 0.887},
#  {'epoch': 96, 'loss': 4.938, 'RRE': 3.978, 'RTE': 0.294, 'RR': 0.979},
#  {'epoch': 97, 'loss': 2.867, 'RRE': 12.79, 'RTE': 0.491, 'RR': 0.883},
#  {'epoch': 98, 'loss': 2.785, 'RRE': 8.692, 'RTE': 0.381, 'RR': 0.908},
#  {'epoch': 99, 'loss': 2.7, 'RRE': 17.554, 'RTE': 0.564, 'RR': 0.795},
#  {'epoch': 100, 'loss': 2.896, 'RRE': 9.216, 'RTE': 0.415, 'RR': 0.866},
#  {'epoch': 101, 'loss': 2.857, 'RRE': 9.483, 'RTE': 0.41, 'RR': 0.862},
#  {'epoch': 102, 'loss': 3.371, 'RRE': 9.775, 'RTE': 0.401, 'RR': 0.879},
#  {'epoch': 103, 'loss': 3.004, 'RRE': 12.683, 'RTE': 0.481, 'RR': 0.866},
#  {'epoch': 104, 'loss': 3.87, 'RRE': 15.074, 'RTE': 0.539, 'RR': 0.812},
#  {'epoch': 105, 'loss': 2.502, 'RRE': 8.96, 'RTE': 0.448, 'RR': 0.828},
#  {'epoch': 106, 'loss': 3.152, 'RRE': 12.51, 'RTE': 0.463, 'RR': 0.816},
#  {'epoch': 107, 'loss': 3.634, 'RRE': 12.48, 'RTE': 0.468, 'RR': 0.866},
#  {'epoch': 108, 'loss': 3.401, 'RRE': 14.71, 'RTE': 0.509, 'RR': 0.837},
#  {'epoch': 109, 'loss': 3.23, 'RRE': 13.132, 'RTE': 0.495, 'RR': 0.803},
#  {'epoch': 110, 'loss': 3.303, 'RRE': 9.476, 'RTE': 0.425, 'RR': 0.854},
#  {'epoch': 111, 'loss': 3.553, 'RRE': 10.593, 'RTE': 0.437, 'RR': 0.866},
#  {'epoch': 112, 'loss': 3.596, 'RRE': 8.726, 'RTE': 0.381, 'RR': 0.9},
#  {'epoch': 113, 'loss': 4.247, 'RRE': 8.42, 'RTE': 0.361, 'RR': 0.925},
#  {'epoch': 114, 'loss': 3.561, 'RRE': 11.116, 'RTE': 0.453, 'RR': 0.891},
#  {'epoch': 115, 'loss': 4.093, 'RRE': 11.126, 'RTE': 0.47, 'RR': 0.887},
#  {'epoch': 116, 'loss': 4.444, 'RRE': 9.94, 'RTE': 0.425, 'RR': 0.87},
#  {'epoch': 117, 'loss': 3.75, 'RRE': 6.584, 'RTE': 0.37, 'RR': 0.912},
#  {'epoch': 118, 'loss': 4.15, 'RRE': 8.987, 'RTE': 0.397, 'RR': 0.874},
#  {'epoch': 119, 'loss': 3.549, 'RRE': 13.469, 'RTE': 0.491, 'RR': 0.849},
#  {'epoch': 120, 'loss': 3.578, 'RRE': 8.556, 'RTE': 0.376, 'RR': 0.941},
#  {'epoch': 121, 'loss': 3.379, 'RRE': 8.854, 'RTE': 0.396, 'RR': 0.883},
#  {'epoch': 122, 'loss': 3.868, 'RRE': 8.138, 'RTE': 0.392, 'RR': 0.887},
#  {'epoch': 123, 'loss': 3.647, 'RRE': 10.619, 'RTE': 0.43, 'RR': 0.862},
#  {'epoch': 124, 'loss': 3.822, 'RRE': 9.375, 'RTE': 0.398, 'RR': 0.925},
#  {'epoch': 125, 'loss': 4.113, 'RRE': 12.069, 'RTE': 0.441, 'RR': 0.858},
#  {'epoch': 126, 'loss': 4.058, 'RRE': 11.783, 'RTE': 0.44, 'RR': 0.883},
#  {'epoch': 127, 'loss': 3.852, 'RRE': 9.485, 'RTE': 0.406, 'RR': 0.904},
#  {'epoch': 128, 'loss': 4.306, 'RRE': 11.195, 'RTE': 0.464, 'RR': 0.879},
#  {'epoch': 129, 'loss': 4.165, 'RRE': 12.72, 'RTE': 0.475, 'RR': 0.874},
#  {'epoch': 130, 'loss': 4.072, 'RRE': 12.114, 'RTE': 0.467, 'RR': 0.841},
#  {'epoch': 131, 'loss': 3.97, 'RRE': 13.23, 'RTE': 0.484, 'RR': 0.879},
#  {'epoch': 132, 'loss': 4.445, 'RRE': 10.817, 'RTE': 0.422, 'RR': 0.841},
#  {'epoch': 133, 'loss': 4.431, 'RRE': 9.281, 'RTE': 0.401, 'RR': 0.862},
#  {'epoch': 134, 'loss': 3.937, 'RRE': 6.213, 'RTE': 0.365, 'RR': 0.883},
#  {'epoch': 135, 'loss': 4.858, 'RRE': 12.567, 'RTE': 0.491, 'RR': 0.812},
#  {'epoch': 136, 'loss': 4.175, 'RRE': 9.08, 'RTE': 0.412, 'RR': 0.887},
#  {'epoch': 137, 'loss': 4.378, 'RRE': 16.691, 'RTE': 0.529, 'RR': 0.845},
#  {'epoch': 138, 'loss': 4.23, 'RRE': 12.552, 'RTE': 0.466, 'RR': 0.891},
#  {'epoch': 139, 'loss': 4.459, 'RRE': 9.263, 'RTE': 0.415, 'RR': 0.845},
#  {'epoch': 140, 'loss': 4.536, 'RRE': 13.324, 'RTE': 0.502, 'RR': 0.803},
#  {'epoch': 141, 'loss': 4.69, 'RRE': 10.646, 'RTE': 0.427, 'RR': 0.874},
#  {'epoch': 142, 'loss': 4.314, 'RRE': 12.168, 'RTE': 0.449, 'RR': 0.854},
#  {'epoch': 143, 'loss': 4.385, 'RRE': 10.261, 'RTE': 0.423, 'RR': 0.879},
#  {'epoch': 144, 'loss': 4.596, 'RRE': 14.431, 'RTE': 0.52, 'RR': 0.828},
#  {'epoch': 145, 'loss': 4.634, 'RRE': 12.621, 'RTE': 0.456, 'RR': 0.866},
#  {'epoch': 146, 'loss': 4.283, 'RRE': 19.433, 'RTE': 0.608, 'RR': 0.791},
#  {'epoch': 147, 'loss': 4.467, 'RRE': 12.356, 'RTE': 0.479, 'RR': 0.849},
#  {'epoch': 148, 'loss': 4.385, 'RRE': 12.932, 'RTE': 0.477, 'RR': 0.866},
#  {'epoch': 149, 'loss': 4.283, 'RRE': 7.7, 'RTE': 0.377, 'RR': 0.891},
#  {'epoch': 150, 'loss': 4.482, 'RRE': 16.424, 'RTE': 0.565, 'RR': 0.799},
#  {'epoch': 151, 'loss': 4.54, 'RRE': 11.472, 'RTE': 0.448, 'RR': 0.854},
#  {'epoch': 152, 'loss': 4.662, 'RRE': 14.006, 'RTE': 0.51, 'RR': 0.828},
#  {'epoch': 153, 'loss': 5.029, 'RRE': 13.839, 'RTE': 0.499, 'RR': 0.883},
#  {'epoch': 154, 'loss': 4.579, 'RRE': 10.648, 'RTE': 0.475, 'RR': 0.849},
#  {'epoch': 155, 'loss': 4.795, 'RRE': 4.615, 'RTE': 0.309, 'RR': 0.967},
#  {'epoch': 156, 'loss': 3.778, 'RRE': 11.082, 'RTE': 0.447, 'RR': 0.87},
#  {'epoch': 157, 'loss': 3.874, 'RRE': 7.288, 'RTE': 0.365, 'RR': 0.916},
#  {'epoch': 158, 'loss': 3.976, 'RRE': 4.674, 'RTE': 0.31, 'RR': 0.887},
#  {'epoch': 159, 'loss': 3.946, 'RRE': 13.513, 'RTE': 0.491, 'RR': 0.858},
#  {'epoch': 160, 'loss': 4.131, 'RRE': 8.136, 'RTE': 0.394, 'RR': 0.9}]

# %%
# plot_validation_data(validation_data)
